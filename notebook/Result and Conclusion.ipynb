# %% [markdown]
# # Results

# %% [markdown]
# ## Test Sample 1

# %%
Recommend_tracks("I Was Appointed",10,show_graph = True)
# Out:
#               Recommended_Songs
# 1           We Glad U Come Over
# 2                          Push
# 3                 Eventide Fire
# 4   Yellowman Is Coming to Town
# 5                   Music Grave
# 6     On And On - Dancehall Mix
# 7                     Buddy Bye
# 8                   Leaving Dub
# 9                Ram Jam Master
# 10            A First Class Dub

# %% [markdown]
# ## Test Sample 2

# %%
Recommend_tracks("Nachangeh Saari Raath (Desi-Tronix Mix)",10,show_graph = True)
# Out:
#                Recommended_Songs
# 1                 Ajab Nain Tere
# 2     Na Ja Re Na Ja Pardes Piya
# 3                           Visa
# 4                  Ghanan Ghanan
# 5   Taal Pe Jab - From "Refugee"
# 6           Kaal Mulaitha Poovae
# 7              Yeh hava yeh bata
# 8         Diwana Kar Ke Chhodoge
# 9                      Boom Boom
# 10                Kaattu Sirukki

# %% [markdown]
# ## Test Sample 3

# %%
Recommend_tracks("Somebody Took My Love",20)
# Out:
#                            Recommended_Songs
# 1                                    I Swear
# 2                      A Better Place - Live
# 3                                 Highwayman
# 4             We Dared The Lightning - Remix
# 5   The Show Must Go On - Remastered Version
# 6                               25 Or 6 To 4
# 7                  Sweet Home Alabama - Live
# 8                               Let It Be Me
# 9                               Silent Night
# 10                          Time Stand Still
# 11                          Pure Imagination
# 12                                Fools Gold
# 13                       Little Green Apples
# 14                              Perhaps Love
# 15               I’ll Be Here In The Morning
# 16                                Wild Geese
# 17                         The Sweetest Gift
# 18                            One More Night
# 19               Thank God I'm A Country Boy
# 20                   Let's Go Shopping Today

# %% [markdown]
# ## Observation

# %% [markdown]
# <b>Sample 1 :</b>
#
# The model recommended 10 songs based on `I Was Appointed`. Recommended songs are printed in the table above. 1st graph displays cosine similarity between recommended songs. Additionally we are plotting feature vs songs on some of the important features that is being used for recommendation.
#
# Our model is returning songs with high cosine similarity, hence a strong recommendation of similar songs.
#
#
# <b>Sample 2 :</b>
#
# We used a hindi song (`Nachangeh Saari Raath (Desi-Tronix Mix)`)for which the model successfully recommended 10 songs, however the recommended songs are not strongly supported by the cosine similarity, which is quite low.
#
#
# <b>Sample 3 :</b>
#
# In this sample test, we could pass the # of songs to be recommended based on the input song.

# %% [markdown]
# # Conclusion

# %% [markdown]
# An advantage of our model is that it allows individual new Songs (not in MPD) to have tracks easily recommended, without the need for extensive computation to iterate and determine its similarity to other existing playlists in MPD. Unfortunately, not computing its similarity with other playlists also means that, latent relationships outside of musicality are ignored. The existing content-based filtering recommender will not be able to identify suitable songs for playlists which are not based on musical features, for example playlists containing female artists or sexual lyrics only.
#
# Since our model is content based, there is certain drawbacks to that. The content-based recommendation engine will only recommend songs related to the genre and other features of songs and may never recommend anything in other categories like songs from a different genre which might be similar. This problem can be solved using another variant of recommendation algorithm known as Collaborative Filtering.
